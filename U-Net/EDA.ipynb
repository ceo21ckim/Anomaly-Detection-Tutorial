# %%
from utils import * 

import numpy as np
import os, glob

import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
img_path = os.path.join(os.getcwd(), 'data/*.tiff')

img_sample = sorted(glob.glob(img_path))[0]

img_sample = tiff2numpy(img_sample)

# %%
plt.imshow(img_sample[:, :, 1]);

# %%
plt.imshow(img_sample[:, :, 29]);
